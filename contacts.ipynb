# %%
contacts=dict()
contacts['venkat']=7075573254
while(True):
    print("Enter your option: ")
    print("1\tInsert\n2\tDisplay\n3\tUpdate\n4\tDelete\n0\tClose Contacts")
    o=int(input())
    if(o==1):
        name=input("Enter the name to add contacts book:")
        if name in contacts:
            print(name,"alredy exists")
        else:
            contacts[name]=input("Enter the mobile number:")
    elif(o==2):
        for i in contacts.keys():
            print(i," ",contacts[i])
    elif(o==3):
        name=input("Enter the name to update:")
        if name in contacts:
            contacts[name]=input("Enter the mobilenumber")
        else:
            print(name,"doesn't exists in contacts")
    elif(o==4):
        name=input("Enter the name to delete:")
        if name in contacts:
            contacts.pop(name)
        else:
            print(name,"doesn't exists in contacts")
    elif(o==0):
        break
# Out:
# Enter your option:
# 1	Insert
# 2	Display
# 3	Update
# 4	Delete
# 0	Close Contacts
# 1
# Enter the name to add contacts book:sai
# Enter the mobile number:9866598470
# Enter your option:
# 1	Insert
# 2	Display
# 3	Update
# 4	Delete
# 0	Close Contacts
# 2
# venkat   7075573254
# sai   9866598470
# Enter your option:
# 1	Insert
# 2	Display
# 3	Update
# 4	Delete
# 0	Close Contacts
# 3
# Enter the name to update:sai
# Enter the mobilenumber9866598470
# Enter your option:
# 1	Insert
# 2	Display
# 3	Update
# 4	Delete
# 0	Close Contacts
# 2
# venkat   7075573254
# sai   9866598470
# Enter your option:
# 1	Insert
# 2	Display
# 3	Update
# 4	Delete
# 0	Close Contacts
# 3
# Enter the name to update:lls
# lls doesn't exists in contacts
# Enter your option:
# 1	Insert
# 2	Display
# 3	Update
# 4	Delete
# 0	Close Contacts
# 3
# Enter the name to update:lls
# lls doesn't exists in contacts
# Enter your option:
# 1	Insert
# 2	Display
# 3	Update
# 4	Delete
# 0	Close Contacts
# 3
# ...
